# %% [markdown]
# # 📘 Unidad 4 · Sesión 6 — Velas Japonesas y Patrones Comunes
#
# ---
#
# ## 🎯 Objetivo
# Interpretar velas japonesas (OHLC), reconocer el significado de el cuerpo/sombras y detectar patrones clásicos (martillo/hammer, envolvente/engulfing, estrella fugaz/shooting star, doji).
#
# ---
#
# ## ⏱️ Duración
# **2 horas**
# - 1 hora teórica (Google Meet / Skool)
# - 1 hora práctica (Google Colab)
#
# ---
#
# ## 📚 Marco Teórico
#
# ### 🕯️ ¿Qué es una vela japonesa?
#
# Una **vela japonesa** representa el movimiento del precio de un activo en un periodo determinado. Está compuesta por:
#
# - **Cuerpo (Body):** Representa la diferencia entre el precio de apertura y el cierre.
#   - Si el cierre > apertura → vela alcista (normalmente verde/blanca).
#   - Si el cierre < apertura → vela bajista (normalmente roja/negra).
#
# - **Mechas/Sombras (Wicks/Shadows):**
#   - **Superior:** Indica el precio máximo alcanzado.
#   - **Inferior:** Indica el precio mínimo alcanzado.
#
# - **Rango total:**
#   $$
#   \text{Rango} = \text{Precio Máximo} - \text{Precio Mínimo}
#   $$
#
# ---
#
# ### 🧠 Psicología detrás de las velas individuales
#
# #### 🔨 Martillo (Hammer)
# - Pequeño cuerpo en la parte superior.
# - Sombra inferior larga (al menos 2 veces el cuerpo).
# - Indica posible **reversión alcista** tras una tendencia bajista.
#
# #### 🌠 Estrella Fugaz (Shooting Star)
# - Cuerpo pequeño en la parte inferior.
# - Sombra superior larga.
# - Indica posible **reversión bajista** tras una tendencia alcista.
#
# #### ➕ Doji
# - Precio de apertura ≈ cierre.
# - Muestra **indecisión del mercado**.
# - Su interpretación depende del contexto y de las velas anteriores/siguientes.
#
# ---
#
# ### 🔄 Patrones de Dos Velas
#
# #### 📈 Envolvente Alcista (Bullish Engulfing)
# - Primera vela: bajista pequeña.
# - Segunda vela: alcista que **envuelve completamente** el cuerpo de la primera.
# - Suele señalar **reversión alcista**.
#
# #### 📉 Envolvente Bajista (Bearish Engulfing)
# - Primera vela: alcista pequeña.
# - Segunda vela: bajista que **envuelve completamente** el cuerpo de la anterior.
# - Suele señalar **reversión bajista**.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
# ### 🧭 Contexto: clave para la interpretación
#
# La **fiabilidad** de los patrones depende del contexto:
#
# - **Tendencia previa:** Un patrón de reversión solo tiene valor si está precedido de una tendencia clara.
# - **Zonas de soporte/resistencia:** Aumentan la validez de un patrón.
# - **Volumen:** Confirmaciones con volumen alto fortalecen la señal.
#
# ---
#
# ### ⚠️ Limitaciones y Falsos Positivos
#
# - Los patrones no siempre anticipan el cambio.
# - Pueden existir **falsos positivos** en mercados laterales o de bajo volumen.
# - **Confirmaciones** (como rompimientos o volumen) son esenciales antes de actuar.
#
# ---
#
# ### 🧪 Fórmulas complementarias
#
# - **Cálculo de cuerpo de la vela:**
#   $$
#   \text{Cuerpo} = | \text{Cierre} - \text{Apertura} |
#   $$
#
# - **Sombra superior:**
#   $$
#   \text{Sombra superior} = \text{Máximo} - \max(\text{Cierre}, \text{Apertura})
#   $$
#
# - **Sombra inferior:**
#   $$
#   \text{Sombra inferior} = \min(\text{Cierre}, \text{Apertura}) - \text{Mínimo}
#   $$
#
# ## 🔗 Lecturas complementarias
# - Steve Nison, *Japanese Candlestick Charting Techniques*.
# - Bulkowski, T., *Encyclopedia of Candlestick Charts*.
# - Investopedia – [Candlestick Patterns](https://www.investopedia.com/trading/candlestick-charting-what-is-it/)
#
# ---

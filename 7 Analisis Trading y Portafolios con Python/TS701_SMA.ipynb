# %% [markdown]
# # 📊 Teoría de Medias Móviles
#
# Las **Medias Móviles (Moving Averages, MA)** son indicadores técnicos que suavizan las series de precios para identificar la **tendencia** subyacente.
# Su objetivo es reducir el "ruido" de los movimientos diarios y facilitar la detección de patrones.
#
# ---
#
# ## 🔹 Media Móvil Simple (SMA)
#
# La **SMA** se calcula como el promedio aritmético de los precios de cierre en los últimos $n$ períodos:
#
# $$
# SMA_t = \frac{1}{n} \sum_{i=0}^{n-1} P_{t-i}
# $$
#
# Donde:
# - $P_t$ = precio en el tiempo $t$
# - $n$ = número de períodos (ej. 20, 50, 200)
#
# **Interpretación:**
# - Si el precio está **por encima** de la SMA → tendencia alcista.
# - Si el precio está **por debajo** de la SMA → tendencia bajista.
#
# ---
#
# ## 🔹 Media Móvil Exponencial (EMA)
#
# La **EMA** da mayor peso a los precios recientes, reaccionando más rápido a cambios de tendencia:
#
# $$
# EMA_t = \alpha P_t + (1 - \alpha) EMA_{t-1}
# $$
#
# con
#
# $$
# \alpha = \frac{2}{n+1}
# $$
#
# ---
#
# ## 🔹 Comparación SMA vs EMA
# - **SMA**: más suave, lenta en reaccionar.
# - **EMA**: más sensible, útil para detectar giros rápidos.
#
# ---
#
# ## 🔹 Cruces de Medias Móviles
#
# Una estrategia clásica consiste en usar dos medias móviles:
# - Una **rápida** (ej. 10 períodos).
# - Una **lenta** (ej. 50 períodos).
#
# - **Golden Cross** (cruce dorado):
#   Cuando la media móvil rápida cruza **por encima** de la lenta → señal alcista.
#
#   $$
#   EMA_{rápida}(t) > EMA_{lenta}(t)
#   $$
#
# - **Death Cross** (cruce de la muerte):
#   Cuando la media móvil rápida cruza **por debajo** de la lenta → señal bajista.
#
#   $$
#   EMA_{rápida}(t) < EMA_{lenta}(t)
#   $$
#
# ---
#
# ## 📊 Interpretación práctica
# - Se usan para **detectar tendencias** y como niveles de **soporte/resistencia dinámicos**.
# - Cuanto mayor el período, **más confiable** es la señal (pero más tardía).
# - Se combinan con otros indicadores (ej. MACD, RSI) para confirmar señales.

# %%
# @title
# !pip install yfinance plotly
import yfinance as yf
import pandas as pd
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from datetime import datetime
from dateutil.relativedelta import relativedelta


# !pip install jupyter nbformat ipykernel ipywidgets
# Out:
# Requirement already satisfied: yfinance in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (0.2.65)
# Requirement already satisfied: plotly in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (6.3.0)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.3.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.2.6)
# Requirement already satisfied: requests>=2.31 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from yfinance) (4.4.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (5.26.1)
# Requirement already satisfied: websockets>=13.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from plotly) (2.5.0)
# Requirement already satisfied: packaging in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from plotly) (25.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from curl_cffi>=0.7->yfinance) (2025.8.3)
# Requirement already satisfied: pycparser in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: jupyter in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (1.1.1)
# Requirement already satisfied: nbformat in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (5.10.4)
# Requirement already satisfied: ipykernel in c:\users\egarcia\appdata\roaming\python\python312\site-packages (6.30.1)
# Requirement already satisfied: ipywidgets in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (8.1.7)
# Requirement already satisfied: notebook in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (7.4.5)
# Requirement already satisfied: jupyter-console in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: jupyterlab in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter) (4.4.7)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: comm>=0.1.1 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipykernel) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipykernel) (9.5.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: colorama in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat) (0.27.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (311)
# Requirement already satisfied: six>=1.5 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from referencing>=0.28.4->jsonschema>=2.6->nbformat) (4.15.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab->jupyter) (80.9.0)
# Requirement already satisfied: anyio in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.10.0)
# Requirement already satisfied: certifi in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: requests>=2.31 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.2.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.23)
# Requirement already satisfied: soupsieve>1.2 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\egarcia\appdata\local\programs\python\python312\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20250822)
# Requirement already satisfied: executing>=1.2.0 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\egarcia\appdata\roaming\python\python312\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)

# %%
# @title
def _to_num(s):
    return pd.to_numeric(s, errors="coerce")

def _fmt2(x):
    try:
        x = float(x)
        return f"{x:.2f}"
    except Exception:
        return "NA"

def plot_interactive_candlestick_ohlc(
    ticker, start_date, end_date,
    ma_fast=10, ma_slow=20, ma_corr=100,
    width=1250, height=900
):
    data = yf.download(ticker, start=start_date, end=end_date, auto_adjust=True, progress=False)
    if isinstance(data.columns, pd.MultiIndex):
        data.columns = data.columns.get_level_values(0)
    if data.empty:
        print(f"No data found for {ticker} between {start_date} and {end_date}")
        return

    for col in ["Open", "High", "Low", "Close", "Volume"]:
        if col in data.columns:
            data[col] = _to_num(data[col])

    data['MA_Fast'] = data['Close'].rolling(window=ma_fast).mean()
    data['MA_Slow'] = data['Close'].rolling(window=ma_slow).mean()
    data['MA_Corr'] = data['Close'].rolling(window=ma_corr).mean()

    hovertext = [
        f"<b>{pd.to_datetime(d).date()}</b><br>"
        f"O:{_fmt2(o)} H:{_fmt2(h)} L:{_fmt2(l)} C:{_fmt2(c)}"
        for d, o, h, l, c in zip(data.index, data['Open'], data['High'], data['Low'], data['Close'])
    ]

    fig = make_subplots(rows=1, cols=1)

    fig.add_trace(go.Candlestick(
        x=data.index,
        open=data['Open'], high=data['High'], low=data['Low'], close=data['Close'],
        name="Candlestick",
        increasing_line_color="#26a69a", decreasing_line_color="#ef5350",
        hovertext=hovertext, hoverinfo="text+x+y",
        visible=True
    ))

    fig.add_trace(go.Ohlc(
        x=data.index,
        open=data['Open'], high=data['High'], low=data['Low'], close=data['Close'],
        name="OHLC",
        increasing_line_color="#26a69a", decreasing_line_color="#ef5350",
        hovertext=hovertext, hoverinfo="text+x+y",
        visible=False
    ))

    fig.add_trace(go.Scatter(
        x=data.index, y=data['MA_Fast'], mode="lines", name=f"SMA {ma_fast}",
        line=dict(color="goldenrod", width=2.2),
        hovertemplate="SMA Rápida: %{y:.2f}<extra></extra>"
    ))
    fig.add_trace(go.Scatter(
        x=data.index, y=data['MA_Slow'], mode="lines", name=f"SMA {ma_slow}",
        line=dict(color="blue", width=2.2),
        hovertemplate="SMA Lenta: %{y:.2f}<extra></extra>"
    ))
    fig.add_trace(go.Scatter(
        x=data.index, y=data['MA_Corr'], mode="lines", name=f"SMA {ma_corr}",
        line=dict(color="purple", width=2.2),
        hovertemplate="SMA Corr: %{y:.2f}<extra></extra>"
    ))
    fig.add_trace(go.Scatter(
        x=data.index, y=data['Close'], mode="lines", name="Close",
        line=dict(width=1.3, dash="dot"), opacity=0.6,
        hovertemplate="Close: %{y:.2f}<extra></extra>"
    ))

    # Botones arriba izquierda
    fig.update_layout(
        updatemenus=[dict(
            type="buttons",
            direction="right",
            x=0.5, y=1.35,                # 👈 coordenadas normalizadas
            xanchor="left", yanchor="top",
            buttons=[
                dict(label="Candlestick", method="update",
                     args=[{"visible": [True, False, True, True, True]}]),
                dict(label="OHLC", method="update",
                     args=[{"visible": [False, True, True, True, True]}]),
            ],
            pad=dict(r=8, t=8, b=8, l=8),
            bgcolor="rgba(240,240,240,0.9)"
        )]
    )

    fig.update_layout(
        title=f"{ticker} — Velas / OHLC con MAs ({start_date} a {end_date})",
        hovermode="x unified",
        xaxis=dict(
            rangeslider=dict(visible=True),
            type="date",
            rangeselector=dict(
                y=1.08, yanchor="top",
                buttons=[
                    dict(count=1, step="month", stepmode="backward", label="1M"),
                    dict(count=3, step="month", stepmode="backward", label="3M"),
                    dict(count=6, step="month", stepmode="backward", label="6M"),
                    dict(step="all", label="All")
                ]
            )
        ),
        yaxis_title="Precio",
        legend=dict(
            orientation="h",
            yanchor="bottom", y=1.35,
            xanchor="center", x=0.5
        ),
        width=width, height=height,
        margin=dict(t=120, r=20, b=60, l=60)
    )

    fig.show()

# %%
#@title Seleccione Acción y Medias Móviles {run:'auto'}
ticker_symbol = "VZ" #@param ["AAPL", "PLTR", "MSFT", "NVDA", "GOOGL", "AMZN", "META", "TSM","BRK.B", "V", "JPM", "XOM", "LLY", "MRK", "UNH", "PG", "MA","CVX", "KO", "PEP", "COST", "TMO", "ORCL", "CSCO", "NKE", "VZ", "ASML", "TXN", "ABT", "TM", "SAP", "AMD", "NFLX", "NOW", "ADBE", "LVMUY", "BABA", "SHEL", "TMUS", "QCOM", "PFE", "SNY", "AZN", "TOT", "GSK", "RIO", "BHP", "MCD​"]
#ticker_symbol = "BTC-USD" #@param ["BTC-USD", "ETH-USD", "USDT-USD", "XRP-USD", "LTC-USD", "ADA-USD", "DOT-USD", "BCH-USD", "XLM-USD", "LINK-USD"]

end_date   =  datetime.today().strftime("%Y-%m-%d")
start_date = (datetime.today() - relativedelta(years=1)).strftime("%Y-%m-%d")
MARapida = 10 #@param {type:"integer"}
MALenta  = 20 #@param {type:"integer"}
MACorr   = 100 #@param {type:"integer"}

# %%
# Uso
plot_interactive_candlestick_ohlc(
    ticker_symbol, start_date, end_date,
    ma_fast=MARapida, ma_slow=MALenta, ma_corr=MACorr,
)

# %%
# 3 Cómo calcular las ganancias con esta estrategia
inversion_inicial = 100_000.00 # usd
# Compras
# 1
golden_cross1 = 39    # Solo cambia el valor aquí
acciones1 = inversion_inicial / golden_cross1
death_cross1 = 41.5  # Solo cambia el valor aquí
ganancia1 = acciones1 * death_cross1
#
print(f"Inversion Inicial {inversion_inicial:,.2f}")
print(f"Acciones Compradas {acciones1:,.2f}")
print(f"Golden Cross {golden_cross1:,.2f}")
print(f"Death Cross {death_cross1:,.2f}")
print(f"Ganancia {ganancia1:,.2f}")
# Out:
# Inversion Inicial 100,000.00
# Acciones Compradas 2,564.10
# Golden Cross 39.00
# Death Cross 41.50
# Ganancia 106,410.26

# %%
# 2
golden_cross2 = 37.7        # Solo cambia el valor aquí
acciones2 = ganancia1 / golden_cross2
death_cross2 = 42.7     # Solo cambia el valor aquí
ganancia2 = acciones2 * death_cross2
#
print(f"Acciones Compradas {acciones2:,.2f}")
print(f"Golden Cross {golden_cross2:,.2f}")
print(f"Death Cross {death_cross2:,.2f}")
print(f"Ganancia {ganancia2:,.2f}")
# Out:
# Acciones Compradas 2,822.55
# Golden Cross 37.70
# Death Cross 42.70
# Ganancia 120,523.02

# %%
# 3
golden_cross3 = 42.2        # Solo cambia el valor aquí
acciones3 = ganancia2 / golden_cross3
death_cross3 = 44.2     # Solo cambia el valor aquí
ganancia3 = acciones3 * death_cross3
#
print(f"Acciones Compradas {acciones3:,.2f}")
print(f"Golden Cross {golden_cross3:,.2f}")
print(f"Death Cross {death_cross3:,.2f}")
print(f"Ganancia {ganancia3:,.2f}")
# Out:
# Acciones Compradas 2,856.00
# Golden Cross 42.20
# Death Cross 44.20
# Ganancia 126,235.01

# %%
# Reporte Final
rendimiento = (ganancia3 - inversion_inicial) / inversion_inicial
print(f"Ganancia Final {ganancia3:,.2f}")
print(f"Rendimiento {rendimiento:,.2%}")
# Out:
# Ganancia Final 126,235.01
# Rendimiento 26.24%

# %% [markdown]
# # TO-DO:
# - Arreglar el GUI para verlo en VSCode
# - Identificar de forma automatica Golden Cross >45 grados de diferencia con la linea azul (EMA 20)

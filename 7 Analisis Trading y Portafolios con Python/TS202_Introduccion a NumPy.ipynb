# %% [markdown]
# ## 📚 Introducción a `NumPy`
#
#
#
# ### 🎯 Objetivo del bloque
#
# - Entender qué es `NumPy` y por qué es base para `pandas` y `scikit-learn`.
# - Trabajar con arrays y operaciones vectorizadas.
# - Comparar su desempeño con listas nativas de Python.
#
#
# ### 🧠 ¿Qué es `NumPy`?
#
# > **NumPy (Numerical Python)** es una librería fundamental para la computación científica en Python.
#
# #### 🔑 Características:
# - Crea arrays y matrices multidimensionales.
# - Realiza operaciones matemáticas vectorizadas eficientes.
# - Es más rápido y menos costoso en memoria que las listas nativas.
#
#
#
# ### 🆚 Listas de Python vs Arrays de NumPy
#
# ```python
# import numpy as np
#
# # Lista en Python
# lista = [1, 2, 3, 4, 5]
# print("Lista + 1 (error):")
# try:
#     print(lista + 1)  # Error
# except:
#     print("No se puede sumar 1 a cada elemento")
#
# # Array en NumPy
# array = np.array([1, 2, 3, 4, 5])
# print("Array + 1 (correcto):")
# print(array + 1)
# ```
# 🔄 Comparación de rendimiento
# ```python
# import time
#
# lista = list(range(1_000_000))
# array = np.array(lista)
#
# start = time.time()
# _ = [x**2 for x in lista]
# print("Tiempo con listas:", time.time() - start)
#
# start = time.time()
# _ = array ** 2
# print("Tiempo con NumPy:", time.time() - start)
#
# ```
#
#
# 🧪 Operaciones básicas con NumPy
# ```python
# a = np.array([10, 20, 30])
# b = np.array([1, 2, 3])
#
# # Operaciones elemento a elemento
# print("Suma:", a + b)
# print("Multiplicación:", a * b)
# print("Media:", a.mean())
# print("Desviación estándar:", a.std())
# ```
#
#
# 📌 Matrices
# ```python
# m = np.array([[1, 2], [3, 4]])
# print("Matriz:\n", m)
# print("Transpuesta:\n", m.T)
# print("Suma de filas:", m.sum(axis=1))
# ```
#
#
# ### 💬 Conclusión
# *	NumPy es rápido, eficiente y la base de librerías como pandas, scikit-learn y tensorflow.
# *	Permite operaciones vectorizadas que no son posibles (o eficientes) con listas de Python.
#
#
# ### 📊 Introducción a Matplotlib
#
# 🎯 Objetivo del bloque
# *	Conocer los tipos de gráficos básicos.
# *	Aprender a configurar leyendas, etiquetas, títulos y estilos.
# *	Visualizar series de tiempo (como precios de acciones).
#
#
# ## 🧠 ¿Qué es matplotlib?
#
# matplotlib es una librería de gráficos en Python que permite crear visualizaciones estáticas, interactivas y personalizables.
#
# #### 📈 Tipos de gráficos más comunes:
# * Gráfica de línea (line plot)
# * Gráfica de barras
# * Histograma
# * Dispersión (scatter)
#
#
# #### 📍 Ejemplo 1: Gráfico de línea
#
# ```python
# import matplotlib.pyplot as plt
#
# dias = ['Lun', 'Mar', 'Mié', 'Jue', 'Vie']
# precios = [100, 110, 105, 115, 120]
#
# plt.plot(dias, precios, marker='o')
# plt.title("Precio de una acción durante la semana")
# plt.xlabel("Día")
# plt.ylabel("Precio ($)")
# plt.grid(True)
# plt.show()
#
# ```
#
# #### 🎨 Estilos y leyendas
# ```python
# plt.plot(dias, precios, label='Empresa X', color='green', linestyle='--')
# plt.legend()
# plt.title("Gráfico con leyenda y estilo personalizado")
# plt.show()
# ```
#
#
# #### 📈 Visualización de series de tiempo financieras
# ```python
# import yfinance as yf
# df = yf.download("GOOGL", start="2023-01-01", end="2024-01-01")
#
# # Solo precios de cierre
# df['Close'].plot(figsize=(12, 5), title="Precio de cierre de GOOGL")
# plt.xlabel("Fecha")
# plt.ylabel("USD")
# plt.grid(True)
# plt.show()
# ```
#
#
# #### 📊 Ejemplo 2: Gráfico de barras
# ```python
# empresas = ['Apple', 'Amazon', 'Meta']
# valores = [175, 142, 210]
#
# plt.bar(empresas, valores, color='orange')
# plt.title("Valor de acciones por empresa")
# plt.ylabel("Precio ($)")
# plt.show()
# ```
#
#
# #### 🧠 Actividad rápida
# 1.	Descarga los precios de "MSFT" y "AAPL".
# 2.	Grafica ambos en una sola figura usando plot().
# 3.	Añade leyendas y títulos.
#
# ```python
# df = yf.download(['MSFT', 'AAPL'], start='2023-01-01', end='2024-01-01')['Close']
# df.plot(figsize=(12, 5), title="Comparación de precios: MSFT vs AAPL")
# plt.xlabel("Fecha")
# plt.ylabel("USD")
# plt.grid(True)
# plt.show()
# ```
#
# ### 💬 Conclusión
# * matplotlib es ideal para visualización exploratoria y análisis descriptivo.
# * Permite comunicar hallazgos de manera clara.
# * Su uso combinado con pandas y numpy potencia el análisis financiero visual.
#
#
# ### 📚 Recursos recomendados
# *	Documentación de NumPy
# *	Documentación de Matplotlib
# *	Libro: Python for Data Analysis, Wes McKinney (creador de pandas)

# %% [markdown]
# ---
#
# ## Teoría para el manejo de Listas, Arreglos y Diccionarios
# **Contenido Extraclase**
#
# La diferencia principal entre una lista y un array depende del contexto, pero normalmente se refiere a cómo se manejan en Python (u otros lenguajes) en cuanto a flexibilidad, tipo de datos y rendimiento.
#
#
# 1. Lista (list en Python)
# *	Tipo de datos: Puede contener elementos de diferentes tipos (enteros, cadenas, objetos, etc.).
# *	Flexibilidad: Muy versátil, permite agregar, eliminar y reorganizar elementos fácilmente.
# *	Tamaño: Dinámico; crece o disminuye según se agreguen o eliminen elementos.
# *	Funciones disponibles: Métodos como .append(), .remove(), .sort(), etc.
# *	Uso común: Cuando se necesita almacenar datos heterogéneos o manipular estructuras de forma flexible.
#   *	Ejemplo:
# ```python
# lista = [1, "hola", 3.14, True]
# ```
#
#
# 2. Array (por ejemplo, numpy.array en Python)
# * Tipo de datos: Todos los elementos son del mismo tipo (int, float, etc.) para optimizar memoria y cálculos.
# * Flexibilidad: Menos flexible para almacenar tipos distintos, pero más eficiente en cálculos numéricos.
# * Tamaño: Fijo una vez creado (aunque se pueden crear nuevos arrays a partir de otros).
# * Funciones disponibles: Operaciones vectorizadas y matemáticas muy rápidas (+, *, funciones trigonométricas, etc.).
# * Uso común: Procesamiento numérico, ciencia de datos, machine learning.
#   *	Ejemplo:
# ```python
# import numpy as np
# array = np.array([1, 2, 3, 4])
# ```
#
#
# **Resumen comparativo**
#
# |Característica	|Lista (list)|	Array (numpy.array)|
# |---|---|---|
# |Tipos de datos	|Mixtos	|Uniformes|
# |Rendimiento	|Más lento en operaciones numéricas|	Muy rápido en cálculos numéricos|
# |Tamaño	|Dinámico	|Fijo (aunque redimensionable creando uno nuevo)|
# |Uso típico	|Datos heterogéneos, manipulación flexible	|Cálculo científico, grandes volúmenes de datos numéricos|
#
#
#
#
# 💡 En pocas palabras:
# * Si necesitas flexibilidad y datos de distintos tipos → usa lista.
# * Si necesitas velocidad y operaciones matemáticas masivas → usa array (por ejemplo, de NumPy).
#
#
# 3. Diccionario (dict en Python)
# * Tipo de datos: Almacena pares clave-valor (key: value).
# * Clave: Debe ser inmutable (ej. string, número, tupla inmutable).
# * Valor: Puede ser cualquier tipo de dato (listas, arrays, otros diccionarios, etc.).
# * Acceso: Muy rápido (búsqueda por clave en tiempo casi constante).
# * Uso común: Modelar datos estructurados (por ejemplo, registros de una base de datos, configuraciones, objetos).
# |* Ejemplo:
# ```python
# diccionario = {
#     "nombre": "Juan",
#     "edad": 30,
#     "activo": True
# }
# print(diccionario["nombre"])  # → Juan
# ```
#
# 4. Diccionario como JSON
#
# En Python, un diccionario (dict) es muy similar a un objeto JSON.
# Esto permite convertirlos fácilmente usando el módulo json:
#
# Ejemplo de conversión
# ```python
# import json
#
# # Diccionario de Python
# usuario = {
#     "nombre": "Ana",
#     "edad": 25,
#     "correo": "ana@example.com",
#     "habilidades": ["Python", "SQL", "Machine Learning"]
# }
#
# # Convertir diccionario → JSON (string)
# json_string = json.dumps(usuario)
# print(json_string)
# # → {"nombre": "Ana", "edad": 25, "correo": "ana@example.com", "habilidades": ["Python", "SQL", "Machine Learning"]}
#
# # Convertir JSON (string) → Diccionario
# usuario_dict = json.loads(json_string)
# print(usuario_dict["habilidades"][0])  # → Python
#
# ```

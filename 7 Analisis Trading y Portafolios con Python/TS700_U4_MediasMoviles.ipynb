# %% [markdown]
# # 📘 Unidad 4 · Sesión 7 — Medias Móviles: SMA vs EMA
#
#
# ## 🎯 Objetivo de la Sesión
#
# Comprender la diferencia entre las medias móviles simples (SMA) y exponenciales (EMA), sus aplicaciones en el análisis técnico y cómo interpretar correctamente sus señales para identificar tendencias, entradas y salidas del mercado.
#
# En esta sesión encontrarás:
#
# - SMA vs EMA (suavizado y retardo).
# - Cruces rápidos vs lentos (señales).
# - Filtro de pendiente (evitar laterales).
# - Parámetros comunes (10/20, 50/200).
# - Visualización y backtest simple.
# - Preparación de práctica.
#
#
# ## ⏱️ Duración Total: 2 Horas
# *	20 min  teórica (explicación y comparación técnica)
# *	1:40 horas práctica (implementación en gráficos reales con Python)
#
#
#
# ## 🧠 Marco Teórico
#
# 📌 ¿Qué son las medias móviles?
#
# Las medias móviles (Moving Averages) son indicadores de tendencia que suavizan el movimiento del precio para identificar su dirección general a lo largo del tiempo.
#
# Sirven para:
#
# *	Confirmar tendencias.
# *	Determinar soportes/resistencias dinámicos.
# *	Generar señales de compra/venta con cruces entre medias.
#
#
# ## 🔹 Media Móvil Simple (SMA)
#
# La SMA (Simple Moving Average) es el promedio aritmético del precio de cierre de un activo durante un número definido de periodos.
#
# Fórmula:
#
# $$
# SMA_t = \frac{P_{t-n+1} + P_{t-n+2} + \ldots + P_t}{n}
# $$
#
# Donde:
# *	P_t = Precio en el tiempo t
# *	n = Número de periodos
#
# ✅ Ventajas:
#
# *	Suaviza el movimiento del precio.
# *	Filtra muchas falsas rupturas.
#
# ❌ Desventajas:
#
# *	Responde lentamente a cambios bruscos.
# *	Señales retrasadas (lagging).
#
#
# ## 🔸 Media Móvil Exponencial (EMA)
#
# La EMA (Exponential Moving Average) da más peso a los precios recientes, haciendo que reaccione más rápido a cambios de mercado.
#
# Fórmula general:
#
# $$
# EMA_t = (P_t \cdot \alpha) + (EMA_{t-1} \cdot (1 - \alpha))
# $$
#
# Donde:
#
# $$
# \alpha = \frac{2}{n+1}
# $$
#
# ✅ Ventajas:
#
# *	Más rápida para detectar cambios de tendencia.
# *	Excelente para identificar momentum.
#
# ❌ Desventajas:
#
# *	Mayor propensión a falsas señales (fakeouts).
# *	Menos estabilidad en rangos laterales.
#
#
# ## ⚖️ Comparación Visual (Resumen)
#
# |Característica|	SMA|	EMA|
# |---|---|---|
# |Respuesta al precio|	Lenta|	Rápida|
# |Suavidad	|Alta|	Media|
# |Ruido (fakeouts)|	Bajo|	Alto|
# |Peso en datos recientes|	Igual para todos	|Mayor peso a los últimos|
# |Ideal para	|Tendencias estables	|Cambios rápidos de dirección|
#
#
#
#
# ## 📊 Aplicaciones Comunes
# *	Cruce dorado (Golden Cross): SMA 50 cruza sobre SMA 200 → señal alcista.
# * Pase de la muerte (Death Cross): SMA 50 cruza debajo de SMA 200 → señal bajista.
# *	EMA 9 y EMA 21: para estrategias de entrada rápida.
# *	SMA 20 como soporte dinámico en tendencias suaves.
#
#
#
# ## 🔎 Interpretación Gráfica
# * Cuando el precio está por encima de la EMA/SMA, se asume tendencia alcista.
# * El cruce de EMA sobre SMA puede indicar aceleración del precio.
# * Cruces entre EMA y SMA generan señales de entrada/salida, pero deben validarse con volumen u otros indicadores.
#
#
# ## 📍 Referencias
# *	Murphy, J. J. (1999). Technical Analysis of the Financial Markets.
# *	Elder, A. (2002). Come Into My Trading Room.
# *	TradingView & Investopedia (consultados para ejemplos y gráficas).
# *	Gráficos generados con yFinance y Plotly.

# %% [markdown]
# ## Golden Cross vs Death Cross
# ![image.png](attachment:image.png)
